# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-0/basics.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/56295530-getting-set-up-video-guide)

# %% [markdown]
# # LangChain Academy
#
# <img src="../../pics/cover_academy.png" width=600>
#
#
#
# Welcome to LangChain Academy!
#
# https://academy.langchain.com/enrollments
#
#
#
# ## Foundation:
#
# ### Introduction to LangChain - Python
#
# <img src="../../pics/cover_LangChain.png" width=600>
#
# https://academy.langchain.com/courses/take/foundation-introduction-to-langchain-python/

# %% [markdown]
# # Module 1: Create Agent
#
# ## Lesson 5: Personal Chef

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\LanchChain_Academy\\Foundation\\Intro_LangChain\\notebooks\\module-1'

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()


@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the wef for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver(),
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {
        "messages": [
            HumanMessage(
                content="I have some leftover chicken and rice. What can I mae?"
            )
        ]
    },
    config,
)

print(response["messages"][-1].content)
# Out:
# Nice—leftover chicken and rice are perfect for quick, cozy meals. Here are several ideas you can make with what you have (and common pantry items). I’ve included a couple of ready-made recipes you can follow if you’d like exact steps.
#
# Options
#
# - Chicken fried rice (15–20 minutes)
#   - What you’ll do: Sauté onion/garlic in a little oil, add shredded chicken and cold rice, push to the side and scramble a couple of eggs, then combine. Stir in soy sauce (and a splash of sesame oil if you have it). Add peas or other veggies if you have them.
#   - Why it’s handy: Fast, uses only pantry staples, and tastes great with a splash of soy sauce or other seasonings.
#   - If you want a tested recipe, you can adapt a generic fried rice method from many sites.
#
# - Creamy chicken and rice casserole (40–60 minutes, baked)
#   - There are a couple of reliable versions you can follow:
#     - Crazy for Crust: Easy Chicken and Rice Casserole (uses leftover chicken and rice, cream soup, cheese, and peas)
#       Link: https://www.crazyforcrust.com/chicken-and-rice-casserole/
#     - Cleverly Simple: Chicken and Rice Casserole (uses cooked chicken, rice, broth, and a creamy sauce; versatile with veggies)
#       Link: https://www.cleverlysimple.com/chicken-and-rice-casserole/
#   - Why it’s handy: Comfort-food staple; easy to customize with whatever veg you have.
#
# - One-pot chicken and rice pilaf (sounds fancy, but simple)
#   - What you’ll do: Sauté onion and garlic, add cooked chicken, stir in rice and broth, season with salt, pepper, and herbs (like thyme or parsley). Simmer until flavors meld and the liquid is absorbed.
#   - Why it’s handy: Deep, savory flavor from simple aromatics; can be a simple “leftovers turned into a cozy meal.”
#
# - Chicken and rice soup (35–45 minutes)
#   - What you’ll do: Simmer chicken with broth, add the rice, and throw in any quick-cooking veggies you have (carrots, celery, greens). Season with salt, pepper, and a pinch of thyme or a bay leaf.
#   - Why it’s handy: Great for a lighter option or when you want something warming.
#
# - Easy chicken rice burrito bowls or nachos (quick, versatile)
#   - What you’ll do: Reheat chicken and rice with a splash of salsa or broth, top with any cheese, avocado, cilantro, and lime. Serve as bowls or layered over tortilla chips.
#
# Would you like me to pull full, step-by-step instructions for one of these? If so, tell me which option you prefer (fried rice, the casseroles, pilaf, or soup), and I’ll fetch a complete recipe and tailor it to what you have on hand. If you have any extra ingredients (vegetables, dairy, eggs, soy sauce, broth), tell me what you’ve got and I’ll customize a recipe for you.
