# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-0/basics.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/56295530-getting-set-up-video-guide)

# %% [markdown]
# # LangChain Academy
#
# <img src="../../pics/cover_academy.png" width=600>
#
#
#
# Welcome to LangChain Academy!
#
# https://academy.langchain.com/enrollments
#
#
#
# ## Foundation:
#
# ### Introduction to LangChain - Python
#
# <img src="../../pics/cover_LangChain.png" width=600>
#
# https://academy.langchain.com/courses/take/foundation-introduction-to-langchain-python/

# %% [markdown]
# # Module 2: Advance Agent
#
# ## Lesson 1: Model Context Protocol (MCP)
#
# ### MCP

# %%
pwd
# Out:
# 'c:\\Users\\crodr\\LanchChain_Academy\\Foundation\\Intro_LangChain\\notebooks\\module-2'

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(
        asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy
    ):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ### Local MCP server

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
            "transport": "stdio",
            "command": "python",
            "args": ["resources/2.1_mcp_server.py"],
        }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content

# %%
from langchain.agents import create_agent

agent = create_agent(model="gpt-5-nano", tools=tools, system_prompt=prompt)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {
        "messages": [
            HumanMessage(content="Tell me about the langchain-mcp-adapters library")
        ]
    },
    config=config,
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Tell me about the langchain-mcp-adapters library', additional_kwargs={}, response_metadata={}, id='c947e0b7-d0d7-4d31-9c63-8f1b3ea3c450'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 156, 'prompt_tokens': 271, 'total_tokens': 427, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhaQ36l6eETv0muPpm7Ts99RVwsKO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e4561-5c38-74e3-a659-0d3725754236-0', tool_calls=[{'name': 'search_web', 'args': {'query': 'langchain-mcp-adapters'}, 'id': 'call_R01Gq3fLxu61ROPpVqmp0WZA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 271, 'output_tokens': 156, 'total_tokens': 427, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "langchain-mcp-adapters",\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph",\n      "title": "Changelog | MCP Adapters for LangChain and LangGraph",\n      "content": "# LangChain Changelog. Sign up for our newsletter to stay up to date. # MCP Adapters for LangChain and LangGraph. The **LangChain MCP Adapters** is a package that makes it easy to use **Anthropic Model Context Protocol (MCP) tools** with LangChain & LangGraph. * Converts **MCP tools** into **LangChain- & LangGraph-compatible tools**. * Enables interaction with tools across multiple **MCP servers**. * Seamlessly integrates the **hundreds of tool servers** already published into LangGraph Agents. ### Why use MCP Adapters:. This adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers. Instead of manually adapting each tool, you can now integrate them seamlessly. It also allows agents to pull from multiple MCP servers at once, making it easier to combine different tools for more powerful applications. MCP is gaining serious traction, and this adapter helps LangGraph agents take full advantage. ##### Subscribe to updates.",\n      "score": 0.99999225,\n      "raw_content": null\n    },\n    {\n      "url": "https://docs.langchain.com/oss/javascript/langchain/mcp",\n      "title": "Model Context Protocol (MCP) - Docs by LangChain",\n      "content": "##### Core components. # Model Context Protocol (MCP). ## Documentation Index. Fetch the complete documentation index at:. `npm install @langchain/mcp-adapters`. `import { MultiServerMCPClient } from \\"@langchain/mcp-adapters\\";. import { ChatAnthropic } from \\"@langchain/anthropic\\";. // Replace with absolute path to your math_server.js file. transport: \\"http\\", // HTTP-based remote server. // Ensure you start your weather server on port 8000. url: \\"http://localhost:8000/mcp\\",. const tools = await client.getTools();. const agent = createAgent({ model: \\"claude-sonnet-4-6\\", tools });`. const mathResponse = await agent.invoke({. const weatherResponse = await agent.invoke({. messages: [{ role: \\"user\\", content: \\"what is the weather in nyc?\\" }],. `import { Server } from \\"@modelcontextprotocol/sdk/server/index.js\\";. import { StdioServerTransport } from \\"@modelcontextprotocol/sdk/server/stdio.js\\";. } from \\"@modelcontextprotocol/sdk/types.js\\";. console.error(\\"Math MCP server running on stdio\\");. import { SSEServerTransport } from \\"@modelcontextprotocol/sdk/server/sse.js\\";. description: \\"Get weather for location\\",. description: \\"Location to get weather for\\",. const { location } = request.params.arguments as { location: string };. const transport = new SSEServerTransport(\\"/mcp\\", res);. console.log(`Weather MCP server running on port ${PORT}`);. ## \u200b Core features.",\n      "score": 0.99999106,\n      "raw_content": null\n    },\n    {\n      "url": "https://github.com/langchain-ai/langchain-mcp-adapters",\n      "title": "GitHub - langchain-ai/langchain-mcp-adapters: LangChain 🔌 MCP · GitHub",\n      "content": "from langchain_mcp_adapters client import MultiServerMCPClient from langchain agents import create_agent client = MultiServerMCPClient \\"math\\" \\"command\\" \\"python\\"# Make sure to update to the full absolute path to your math_server.py file \\"args\\"\\"/path/to/math_server.py\\" \\"transport\\" \\"stdio\\" \\"weather\\" # Make sure you start your weather server on port 8000 \\"url\\"\\"http://localhost:8000/mcp\\" \\"transport\\" \\"http\\" tools = await client get_tools agent = create_agent\\"openai:gpt-4.1\\" tools math_response = await agent ainvoke \\"messages\\"\\"what\'s (3 + 5) x 12?\\" weather_response = await agent ainvoke \\"messages\\" \\"what is the weather in nyc?\\". from langcha ...
#               AIMessage(content='Here’s a concise overview of the LangChain MCP Adapters library (often referred to as langchain-mcp-adapters).\n\nWhat it is\n- A bridge between the Model Context Protocol (MCP) tool servers and LangChain/LangGraph.\n- Lets you convert MCP tools, prompts, and resources into LangChain- and LangGraph-compatible constructs.\n- Enables interaction with many MCP servers at once, letting LangChain/LangGraph agents pull tools from multiple MCP sources.\n\nKey capabilities\n- Tools adapters: MCP tools are converted into LangChain-compatible tools so you can call them from LangChain agents.\n- Prompts and resources adapters: MCP prompts and media/resources are mapped to LangChain representations (prompts, blobs, etc.).\n- Multi-server access: A client (e.g., MultiServerMCPClient) can connect to multiple MCP servers and load tools/prompts/resources from them.\n- Session and transport support: Works with different MCP transport types (stdio, HTTP, SSE, etc.), making it possible to hook up local or remote MCP servers.\n- Integrates with LangChain and LangGraph agents to orchestrate tool usage across MCP servers.\n\nWhere to learn more\n- Changelog announcement: MCP Adapters for LangChain and LangGraph (high-level overview and motivation)\n  https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph\n- LangChain MCP Adapters docs (Model Context Protocol section)\n  https://docs.langchain.com/oss/javascript/langchain/mcp\n  Note: This page shows the JavaScript/TypeScript usage and installation instructions (npm install @langchain/mcp-adapters).\n- LangChain MCP Adapters reference (Python-style module overview)\n  https://reference.langchain.com/python/langchain-mcp-adapters/langchain_mcp_adapters\n- GitHub repository\n  https://github.com/langchain-ai/langchain-mcp-adapters\n- PyPI (Python packaging)\n  https://pypi.org/project/langchain-mcp-tools/\n\nGetting started (high level)\n- Installation\n  - JavaScript/TypeScript: npm install @langchain/mcp-adapters\n  - Python (MCP adapters for Python): typically via the langchain-mcp-tools package on PyPI\n    (e.g., pip install langchain-mcp-tools)\n- Basic usage concepts\n  - Create a MultiServerMCPClient configured with your MCP servers and transports.\n  - Retrieve MCP tools via the client (e.g., get_tools()) and feed them into a LangChain/LangGraph agent.\n  - Run the agent to invoke MCP tools across one or more MCP servers.\n- Typical workflow\n  - Start one or more MCP servers (e.g., math_server.py, weather_server.py) with the MCP protocol.\n  - Open a LangChain/LangGraph application and connect to those MCP endpoints via the MCP adapters.\n  - The agent can choose among tools from multiple MCP servers as needed.\n\nQuick example ideas (high level)\n- TypeScript/JS (conceptual)\n  - Create a MultiServerMCPClient with server definitions (tool families like math, weather) and transports (stdio, http).\n  - Load tools from the MCP servers.\n  - Create a LangChain agent with those tools and run prompts that call MCP-based tools.\n- Python (conceptual)\n  - Use the Python MCP adapters client to connect to MCP servers.\n  - Retrieve tool definitions, wrap them as LangChain tools, and pass them to a LangChain agent.\n  - Invoke the agent with user messages; the agent delegates to MCP tools as needed.\n\nIf you tell me which language you’re using (Python vs JavaScript/TypeScript) and what you want to build (e.g., a simple calculator across MCP tools, or a weather inquiry that pulls from multiple MCP servers), I can give you a concrete minimal code sample tailored to that stack.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2210, 'prompt_tokens': 1931, 'total_tokens': 4141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_prov ...

# %%
print(response["messages"][-1].content)
# Out:
# Here’s a concise overview of the LangChain MCP Adapters library (often referred to as langchain-mcp-adapters).
#
# What it is
# - A bridge between the Model Context Protocol (MCP) tool servers and LangChain/LangGraph.
# - Lets you convert MCP tools, prompts, and resources into LangChain- and LangGraph-compatible constructs.
# - Enables interaction with many MCP servers at once, letting LangChain/LangGraph agents pull tools from multiple MCP sources.
#
# Key capabilities
# - Tools adapters: MCP tools are converted into LangChain-compatible tools so you can call them from LangChain agents.
# - Prompts and resources adapters: MCP prompts and media/resources are mapped to LangChain representations (prompts, blobs, etc.).
# - Multi-server access: A client (e.g., MultiServerMCPClient) can connect to multiple MCP servers and load tools/prompts/resources from them.
# - Session and transport support: Works with different MCP transport types (stdio, HTTP, SSE, etc.), making it possible to hook up local or remote MCP servers.
# - Integrates with LangChain and LangGraph agents to orchestrate tool usage across MCP servers.
#
# Where to learn more
# - Changelog announcement: MCP Adapters for LangChain and LangGraph (high-level overview and motivation)
#   https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph
# - LangChain MCP Adapters docs (Model Context Protocol section)
#   https://docs.langchain.com/oss/javascript/langchain/mcp
#   Note: This page shows the JavaScript/TypeScript usage and installation instructions (npm install @langchain/mcp-adapters).
# - LangChain MCP Adapters reference (Python-style module overview)
#   https://reference.langchain.com/python/langchain-mcp-adapters/langchain_mcp_adapters
# - GitHub repository
#   https://github.com/langchain-ai/langchain-mcp-adapters
# - PyPI (Python packaging)
#   https://pypi.org/project/langchain-mcp-tools/
#
# Getting started (high level)
# - Installation
#   - JavaScript/TypeScript: npm install @langchain/mcp-adapters
#   - Python (MCP adapters for Python): typically via the langchain-mcp-tools package on PyPI
#     (e.g., pip install langchain-mcp-tools)
# - Basic usage concepts
#   - Create a MultiServerMCPClient configured with your MCP servers and transports.
#   - Retrieve MCP tools via the client (e.g., get_tools()) and feed them into a LangChain/LangGraph agent.
#   - Run the agent to invoke MCP tools across one or more MCP servers.
# - Typical workflow
#   - Start one or more MCP servers (e.g., math_server.py, weather_server.py) with the MCP protocol.
#   - Open a LangChain/LangGraph application and connect to those MCP endpoints via the MCP adapters.
#   - The agent can choose among tools from multiple MCP servers as needed.
#
# Quick example ideas (high level)
# - TypeScript/JS (conceptual)
#   - Create a MultiServerMCPClient with server definitions (tool families like math, weather) and transports (stdio, http).
#   - Load tools from the MCP servers.
#   - Create a LangChain agent with those tools and run prompts that call MCP-based tools.
# - Python (conceptual)
#   - Use the Python MCP adapters client to connect to MCP servers.
#   - Retrieve tool definitions, wrap them as LangChain tools, and pass them to a LangChain agent.
#   - Invoke the agent with user messages; the agent delegates to MCP tools as needed.
#
# If you tell me which language you’re using (Python vs JavaScript/TypeScript) and what you want to build (e.g., a simple calculator across MCP tools, or a weather inquiry that pulls from multiple MCP servers), I can give you a concrete minimal code sample tailored to that stack.
