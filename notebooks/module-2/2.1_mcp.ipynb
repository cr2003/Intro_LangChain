# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(
        asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy
    ):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ## Local MCP server

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
            "transport": "stdio",
            "command": "python",
            "args": ["resources/2.1_mcp_server.py"],
        }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content

# %%
from langchain.agents import create_agent

agent = create_agent(model="gpt-5-nano", tools=tools, system_prompt=prompt)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {
        "messages": [
            HumanMessage(content="Tell me about the langchain-mcp-adapters library")
        ]
    },
    config=config,
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Tell me about the langchain-mcp-adapters library', additional_kwargs={}, response_metadata={}, id='1e7e950e-14d1-4336-aa5d-faaadbe16551'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 271, 'total_tokens': 363, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhXRgthvFlcGXmTTI0G1pSN3D2hOW', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e44b2-f051-7d02-a7b6-c51b9f2c6063-0', tool_calls=[{'name': 'search_web', 'args': {'query': 'langchain-mcp-adapters'}, 'id': 'call_NNfTr6OWrCuOckH2uBcsyH9z', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 271, 'output_tokens': 92, 'total_tokens': 363, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "langchain-mcp-adapters",\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph",\n      "title": "Changelog | MCP Adapters for LangChain and LangGraph",\n      "content": "# LangChain Changelog. Sign up for our newsletter to stay up to date. # MCP Adapters for LangChain and LangGraph. The **LangChain MCP Adapters** is a package that makes it easy to use **Anthropic Model Context Protocol (MCP) tools** with LangChain & LangGraph. * Converts **MCP tools** into **LangChain- & LangGraph-compatible tools**. * Enables interaction with tools across multiple **MCP servers**. * Seamlessly integrates the **hundreds of tool servers** already published into LangGraph Agents. ### Why use MCP Adapters:. This adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers. Instead of manually adapting each tool, you can now integrate them seamlessly. It also allows agents to pull from multiple MCP servers at once, making it easier to combine different tools for more powerful applications. MCP is gaining serious traction, and this adapter helps LangGraph agents take full advantage. ##### Subscribe to updates.",\n      "score": 0.99999225,\n      "raw_content": null\n    },\n    {\n      "url": "https://github.com/langchain-ai/langchain-mcp-adapters",\n      "title": "LangChain MCP Adapters - GitHub",\n      "content": "from langchain_mcp_adapters client import MultiServerMCPClient from langchain agents import create_agent client = MultiServerMCPClient \\"math\\" \\"command\\" \\"python\\"# Make sure to update to the full absolute path to your math_server.py file \\"args\\"\\"/path/to/math_server.py\\" \\"transport\\" \\"stdio\\" \\"weather\\" # Make sure you start your weather server on port 8000 \\"url\\"\\"http://localhost:8000/mcp\\" \\"transport\\" \\"http\\" tools = await client get_tools agent = create_agent\\"openai:gpt-4.1\\" tools math_response = await agent ainvoke \\"messages\\"\\"what\'s (3 + 5) x 12?\\" weather_response = await agent ainvoke \\"messages\\" \\"what is the weather in nyc?\\". from langchain_mcp_adapters client import MultiServerMCPClient from langgraph graph import StateGraph MessagesState START from langgraph prebuilt import ToolNode tools_condition from langchain chat_models import init_chat_model model = init_chat_model\\"openai:gpt-4.1\\" client = MultiServerMCPClient \\"math\\" \\"command\\" \\"python\\"# Make sure to update to the full absolute path to your math_server.py file \\"args\\"\\"./examples/math_server.py\\" \\"transport\\" \\"stdio\\" \\"weather\\" # make sure you start your weather server on port 8000 \\"url\\"\\"http://localhost:8000/mcp\\" \\"transport\\" \\"http\\" tools = await client get_tools def call_model state MessagesState response = model bind_tools tools invoke state \\"messages\\" return \\"messages\\" response builder = StateGraph MessagesState builder add_node call_model builder add_node ToolNode tools builder add_edge START \\"call_model\\" builder add_conditional_edges \\"call_model\\" tools_condition builder add_edge \\"tools\\" \\"call_model\\" graph = builder compile math_response = await graph ainvoke \\"messages\\"\\"what\'s (3 + 5) x 12?\\" weather_response = await graph ainvoke \\"messages\\" \\"what is the weather in nyc?\\".",\n      "score": 0.999985,\n      "raw_content": null\n    },\n    {\n      "url": "https://reference.langchain.com/python/langchain-mcp-adapters/langchain_mcp_adapters",\n      "title": "langchain_mcp_adapters | LangChain Reference",\n      "content": "##### LangChain. ##### LangChain Core. ##### MCP Adapters. ## LangChain Assistant. LangChain MCP Adapters - Connect MCP servers with LangChain applications. This package provides adapters to connect MCP (Model Context Protocol) servers. with LangCha ...
#               AIMessage(content='Here’s a concise overview of the langchain-mcp-adapters library and what it does.\n\nWhat it is\n- The LangChain MCP Adapters library provides adapters to connect MCP (Model Context Protocol) tool servers with LangChain (and LangGraph) applications.\n- It converts MCP tools, prompts, and resources into LangChain-LangGraph compatible forms, enabling you to use MCP tool servers from LangChain agents and workflows.\n- It supports interacting with tools across multiple MCP servers and integrating many MCP tools into LangGraph agents.\n\nKey benefits\n- Easy cross-server integration: Use hundreds of MCP tool servers without writing custom adapters for each one.\n- Multi-server orchestration: Agents can pull tools from multiple MCP servers at once, enabling richer tool ecosystems.\n- Bridges MCP and LangChain/LangGraph: Tools, prompts, and resources from MCP servers are converted into LangChain-compatible constructs.\n\nCore components and concepts (high level)\n- MCP Adapters: Convert MCP tools, prompts, and resources into LangChain-compatible equivalents.\n- MultiServerMCPClient: A client for connecting to and loading tools/resources from multiple MCP servers.\n- Session management: Supports different MCP transport types and session lifecycles.\n- Tools interceptor and lifecycle hooks: Interfaces for managing the lifecycle of MCP tool calls within LangChain/LangGraph.\n- LangGraph collaboration: Integrates MCP tools into LangGraph paths and tool nodes for graph-based reasoning.\n\nWhere to find and how to learn more\n- GitHub: langchain-ai/langchain-mcp-adapters\n  - This is the official repository with code, examples, and usage notes.\n- PyPI: langchain-mcp-tools\n  - The Python package page for the MCP adapters toolset and related utilities.\n- Node (JavaScript/TypeScript): @langchain/mcp-adapters\n  - npm package for Node.js users.\n- Documentation and references:\n  - LangChain Reference (Python): langchain_mcp_adapters module overview and API docs\n  - Changelog announcement: MCP Adapters for LangChain and LangGraph\n    - This provides context on the purpose and capabilities as they were introduced and evolved.\n\nTypical usage (high level)\n- In Python:\n  - Install the MCP adapters package (e.g., via PyPI).\n  - Create a MultiServerMCPClient to connect to one or more MCP servers.\n  - Load MCP tools/resources and adapt them into LangChain tools/prompts/resources.\n  - Use these adapted tools inside LangChain or LangGraph workflows (e.g., with agents or graph-based tool invocation).\n- In Node.js:\n  - Install the @langchain/mcp-adapters package.\n  - Similar flow: connect to MCP servers, load tools, and integrate into LangChain-LangGraph workflows.\n\nQuick-start (high level, for guidance)\n- Python\n  - pip install langchain-mcp-tools\n  - Explore examples in the GitHub repo to see how MultiServerMCPClient is instantiated and how tools are loaded and invoked within a LangChain agent.\n- Node\n  - npm install @langchain/mcp-adapters\n  - See examples in the repository/documentation for wiring MCP tools into LangChain/LangGraph nodes and agents.\n\nIf you’d like, I can pull and summarize specific sections from:\n- The GitHub repo (setup, quickstart, and examples)\n- The Python reference docs (exact API usage for MultiServerMCPClient, prompts/resources/tools adapters)\n- The changelog announcement for MCP Adapters\n\nWould you like:\n- A Python quickstart snippet showing how to connect to multiple MCP servers and load tools into a LangChain agent?\n- A Node.js quickstart snippet with the same flow?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2167, 'prompt_tokens': 1604, 'total_tokens': 3771, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt ...

# %% [markdown]
# ## Online MCP

# %%
client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "uvx",
            "args": ["mcp-server-time", "--local-timezone=America/New_York"],
        }
    }
)

tools = await client.get_tools()

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
question = HumanMessage(content="What time is it?")

response = await agent.ainvoke({"messages": [question]})

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What time is it?', additional_kwargs={}, response_metadata={}, id='9652577c-5a6d-4f3c-a6ed-b964b7d8f37e'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 155, 'prompt_tokens': 296, 'total_tokens': 451, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhXVSl0JmAdZdLWV9cbtnyMBlVTjn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e44b6-84f6-7b11-9d82-37458e85fa7c-0', tool_calls=[{'name': 'get_current_time', 'args': {'timezone': 'America/New_York'}, 'id': 'call_59vxkKXNPJJspAb1Cn2plyNR', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 296, 'output_tokens': 155, 'total_tokens': 451, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "timezone": "America/New_York",\n  "datetime": "2026-05-20T05:27:56-04:00",\n  "day_of_week": "Wednesday",\n  "is_dst": true\n}', 'id': 'lc_a8d6a5ba-2f5e-40ec-af9e-cbbd75c56b72'}], name='get_current_time', id='0ef393c2-1c39-471a-a6c6-278e49bd4777', tool_call_id='call_59vxkKXNPJJspAb1Cn2plyNR'),
#               AIMessage(content='In America/New_York, it’s 5:27 AM on Wednesday, May 20, 2026 (Eastern Daylight Time, UTC-4). Want this in another timezone?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 432, 'prompt_tokens': 379, 'total_tokens': 811, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhXVWSVET5WegybFH3L9POCJoGhJj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e44b6-934d-77d2-a97a-b38417ed34c4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 379, 'output_tokens': 432, 'total_tokens': 811, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}
