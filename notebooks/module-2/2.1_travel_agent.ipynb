# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {"travel_server": {"transport": "streamable_http", "url": "https://mcp.kiwi.com"}}
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions.",
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {
        "messages": [
            HumanMessage(
                content="Get me a direct flight from San Francisco to Tokyo on March 31st"
            )
        ]
    },
    # {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on May 31st")]},
    config,
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='09f5c5e7-b2ea-4be2-bb0d-06df35473b47'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 709, 'prompt_tokens': 1229, 'total_tokens': 1938, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhZigD3EAkRpPa0PqBVyoO2pP3FEp', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e4538-5a94-7d50-be3a-ac23e397f85a-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2027', 'departureDateFlexRange': 0, 'passengers': {'adults': 1}, 'cabinClass': 'M', 'curr': 'USD', 'locale': 'en'}, 'id': 'call_zjrO9z0LZciEh92cVI1FD5Pb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 709, 'total_tokens': 1938, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:25:00.000Z",\n      "local": "2027-03-31T00:25:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T10:40:00.000Z",\n      "local": "2027-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 98100,\n    "durationInSeconds": 98100,\n    "price": 683,\n    "deepLink": "https://on.kiwi.com/6dMuk3",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:15:00.000Z",\n          "local": "2027-04-01T05:15:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-01T07:20:00.000Z",\n          "local": "2027-04-01T15:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:50:00.000Z",\n      "local": "2027-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T03:55:00.000Z",\n      "local": "2027-04-01T12:55:00.000"\n    },\n    "totalDurationInSeconds": 72300,\n    "durationInSeconds": 72300,\n    "price": 644,\n    "deepLink": "https://on.kiwi.com/nQhNga",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:25:00.000Z",\n          "local": "2027-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-01T00:30:00.000Z",\n          "local": "2027-04-01T08:30:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:50:00.000Z",\n      "local": "2027-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T06:05:00.000Z",\n      "local": "2027-04-01T15:05:00.000"\n    },\n    "totalDurationInSeconds": 80100,\n    "durationInSeconds": 80100,\n    "price": 647,\n    "deepLink": "https://on.kiwi.com/HGekHT",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:25:00.000Z",\n          "local": "2027-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-01T02:40:00.000Z",\n          "local": "2027-04-01T10:40:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:50:00.000Z",\n      "local": "2027-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T10:25:00.000Z",\n      "local": "2027-04-01T19:25:00.000"\n    },\n    "totalDurationInSeconds": 95700,\n    "durationInSeconds": 95700,\n    "price": 647,\n    "deepLink": "https://on.kiwi.com/QFxUSS",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2027-03-31T21:25:00.000Z",\n          "local": "2027-04-01T05:25:00.000"\n        },\n        "departure": {\n          "utc": "2027-04-01T07:00:00.000Z",\n          "local": "2027-04-01T15:00:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2027-03-31T07:50:00.000Z",\n      "local": "2027-03-31T00:50:00.000"\n    },\n    "arrival": {\n      "utc": "2027-04-01T10:40:00.000Z",\n      "local": "2027-04-01T19:40:00.000"\n    },\n    "totalDurationInSeconds": 96600,\n    "durationInSeconds": 96600,\n    "price": 683,\n    "deepLink": "https://on.kiwi.com/ ...
#               AIMessage(content='Here’s the direct flight I found from San Francisco to Tokyo (Haneda) for March 31, 2027.\n\n| Route | Times (local) and duration | Cabin | Price | Booking link |\n|---|---|---|---|---|\n| SFO → HND | 31/03 01:45 → 01/04 05:00 (11h 15m) | Economy | USD 1,245 | https://on.kiwi.com/XiUVaS |\n\nBest price: USD 1,245 (direct, nonstop).  \nShortest duration: 11h 15m (direct).  \nRecommendation: This direct nonstop is the simplest option—great if you want to minimize travel time without layovers.\n\nHave a nice trip! Fun fact: Tokyo is home to Shibuya Crossing, one of the busiest pedestrian crossings in the world.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 5055, 'prompt_tokens': 6109, 'total_tokens': 11164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 4864, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DhZiowU0GoNQJKKPNmz5R9a94gxEX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e4538-79a2-79d1-bd63-ad85ed0de42e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6109, 'output_tokens': 5055, 'total_tokens': 11164, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 4864}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here’s the direct flight I found from San Francisco to Tokyo (Haneda) for March 31, 2027.
#
# | Route | Times (local) and duration | Cabin | Price | Booking link |
# |---|---|---|---|---|
# | SFO → HND | 31/03 01:45 → 01/04 05:00 (11h 15m) | Economy | USD 1,245 | https://on.kiwi.com/XiUVaS |
#
# Best price: USD 1,245 (direct, nonstop).
# Shortest duration: 11h 15m (direct).
# Recommendation: This direct nonstop is the simplest option—great if you want to minimize travel time without layovers.
#
# Have a nice trip! Fun fact: Tokyo is home to Shibuya Crossing, one of the busiest pedestrian crossings in the world.
